# %% [markdown]
# pandas sayesinde gerçek hayat veri setlerini analiz edebiliri. Veri analizindeki en çok kullanılan kütüphanedir.

# %%
import pandas as pd

pd.DataFrame(data = {'Yes' : [50,21], 'No' : [131,2]}, index=['Bayrampaşa','Maltepe'])
# Out:
#             Yes   No
# Bayrampaşa   50  131
# Maltepe      21    2

# %%
pd.DataFrame({'Emre' : ['Yemek Çok Güzeldi','Nefisti'], 'Alper' : ['Islama Köfte olmamış', 'Beğenmedim']}, index=['Meşhur Islamacı','Pilav Sarayı'])
# Out:
#                               Emre                 Alper
# Meşhur Islamacı  Yemek Çok Güzeldi  Islama Köfte olmamış
# Pilav Sarayı               Nefisti            Beğenmedim

# %% [markdown]
# # Series

# %% [markdown]
# DataFrame bir tablodur. Series ise bir listedir. Aslında Tablonun liste formuna getirilmiş hali diyebiliriz.

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([131,145,212,421,342,412,123], index = ['Pazartesi','Salı','Çarşamba','Perşembe','Cuma','Cumartesi','Pazar'], name='Haftalık Kitap Satışları')
# Out:
# Pazartesi    131
# Salı         145
# Çarşamba     212
# Perşembe     421
# Cuma         342
# Cumartesi    412
# Pazar        123
# Name: Haftalık Kitap Satışları, dtype: int64

# %%
data_yolu = '/workspaces/H05_Veri_Analizi_EDA/winemag-data-130k-v2.csv'
pd.read_csv(data_yolu)
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 59575       59575         US
# 59576       59576  Australia
# 59577       59577      Italy
# 59578       59578         US
# 59579       59579         US
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 59575  Delicious in briary blackberry jam, cherry pie...
# 59576  Like the D&J; Chardonnay, this is a readily ap...
# 59577  Straightforward and honest, this bright Rosso ...
# ...

# %%
pd.DataFrame({'Apples' : [30], 'Bananas' : [21]})
# Out:
#    Apples  Bananas
# 0      30       21

# %%
pd.DataFrame({'Apples' : [35,41], 'Bananas' : [21,34]}, index=['2017 Sales','2018 Sales'])
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# # Indexleme, Seçme ve Atama İşlemleri

# %%
df = pd.read_csv(data_yolu, index_col = 0)
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df.tail()
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
for sütun in df.columns:
    print(sütun)
# Out:
# country
# description
# designation
# points
# price
# province
# region_1
# region_2
# taster_name
# taster_twitter_handle
# title
# variety
# winery

# %%
df[['taster_twitter_handle','winery']]
# Out:
#        taster_twitter_handle                                    winery
# 0               @kerinokeefe                                   Nicosia
# 1                 @vossroger                       Quinta dos Avidagos
# 2                @paulgwine                                  Rainstorm
# 3                        NaN                                St. Julian
# 4                @paulgwine                               Sweet Cheeks
# ...                      ...                                       ...
# 129966                   NaN  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967           @paulgwine                                   Citation
# 129968            @vossroger                           Domaine Gresser
# 129969            @vossroger                      Domaine Marcel Deiss
# 129970            @vossroger                          Domaine Schoffit
#
# [129971 rows x 2 columns]

# %% [markdown]
# Pandas Indexing Methods

# %%
df.iloc[1246]
# Out:
# country                                                                 US
# description              A polished, supple Cabernet with real class an...
# designation                                                            NaN
# points                                                                  88
# price                                                                 40.0
# province                                                        California
# region_1                                                        Rutherford
# region_2                                                              Napa
# taster_name                                                            NaN
# taster_twitter_handle                                                  NaN
# title                    Provenance Vineyards 2005 Cabernet Sauvignon (...
# variety                                                 Cabernet Sauvignon
# ...

# %%
df.iloc[100:750,12]
# Out:
# 100               Ventosa
# 101     Lamoreaux Landing
# 102     Lamoreaux Landing
# 103                 Leyda
# 104          Madonna Alta
#               ...
# 745            Ribafreixo
# 746         Jacob's Creek
# 747       William Knuttel
# 748            Casa Larga
# 749    Cave de Beblenheim
# Name: winery, Length: 650, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
df.iloc[-75:,3:5]
# Out:
#         points  price
# 129896      91   36.0
# 129897      91   48.0
# 129898      91   52.0
# 129899      91   30.0
# 129900      91   32.0
# ...        ...    ...
# 129966      90   28.0
# 129967      90   75.0
# 129968      90   30.0
# 129969      90   32.0
# 129970      90   21.0
#
# [75 rows x 2 columns]

# %% [markdown]
# # Şarta Göre Indexlemeler

# %%
df['country'] == 'Turkey'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
df[df['country'] == 'Turkey']
# Out:
#        country                                        description  \
# 1187    Turkey  From a winery that specializes in this rare va...
# 3343    Turkey  Made of Kinali Yapincak, a grape native to Tur...
# 7685    Turkey  Aromas of cherry, raspberry and buttered toast...
# 8778    Turkey  Made of Kalecik Karasi, an indigenous Turkish ...
# 8779    Turkey  Light straw in color, this wine offers aromas ...
# ...        ...                                                ...
# 126940  Turkey  A nose of raspberry, brambles and confectioner...
# 127078  Turkey  A nose of cherry, white peach and jalapeño set...
# 127835  Turkey  This blend of 34% Merlot, 26% Cabernet Sauvign...
# 127911  Turkey  This wine is red-violet in colour and has a no...
# 129774  Turkey  Aromas of black cherry and green pepper lead i...
#
#                                            designation  points  price  \
# 1187                                               NaN      88   20.0
# ...

# %%
df[(df.price < 15) & (df.points > 90)]
# Out:
#          country                                        description  \
# 127       France  Attractive mid-gold color with intense aromas ...
# 156      Germany  Approachably fruity yet nuanced and electrifyi...
# 3017     Austria  This is a powerful, wood-aged wine. It's still...
# 5051          US  With rich melon aromas, ripe apple flavors and...
# 5054    Portugal  The Reserva version of Mural makes a powerful ...
# ...          ...                                                ...
# 123837    France  This wine is a perennial overachiever, but the...
# 126783  Portugal  The flagship white from Bacalhôa is a full-bod...
# 126792  Portugal  The partner to Aveleda's pure Touriga Nacional...
# 127554        US  This is an unbelievable price for a Napa Merlo...
# 128010        US  A classic Washington tasting-room Riesling—onl...
#
#                           designation  points  price        province  \
# 127                        Alsace One      91   13.0          Alsace
# ...
